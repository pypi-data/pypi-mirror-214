# %% [markdown]
# # Presentation Topic
# ### Presented by your name
# ### Date: xx/xx/xxxx

# %% [markdown]
# Greetings; Introduce yourself

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# <audio controls src="slides_audios/PresentationTopic.mp3">

# %% [markdown]
# ## Background

# %% [markdown]
# - item 1
# - item 2
# - item 3

# %% [markdown]
# Recently, x = 3

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Background.mp3">

# %% [markdown]
# # Item 1
# - intro 1
# - intro 2

# %% [markdown]
# intro for background

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# <audio controls src="slides_audios/Item1.mp3">

# %% [markdown]
# Practice time!
