# %% [markdown]
# # Presentation Topic
# ### Presented by your name
# ### Date: xx/xx/xxxx

# %% [markdown]
# Greetings; Introduce yourself

# %% [markdown]
# ## Background

# %% [markdown]
# - item 1
# - item 2
# - item 3

# %% [markdown]
# Recently, x = 3

# %% [markdown]
# # Item 1
# - intro 1
# - intro 2

# %% [markdown]
# intro for background

# %% [markdown]
# Practice time!
